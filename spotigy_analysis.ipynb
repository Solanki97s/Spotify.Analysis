# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mp
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\252ha\Desktop\DATA ANALYST\dataset\spotify-2023.csv',encoding='unicode_escape')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  bpm                   953 non-null    int64
#  14  music_mode            953 non-null    object
# ...

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  in_deezer_charts  \
# ...

# %%
pd.isnull(df)
# Out:
#      track_name  artist(s)_name  artist_count  released_year  released_month  \
# 0         False           False         False          False           False
# 1         False           False         False          False           False
# 2         False           False         False          False           False
# 3         False           False         False          False           False
# 4         False           False         False          False           False
# ..          ...             ...           ...            ...             ...
# 948       False           False         False          False           False
# 949       False           False         False          False           False
# 950       False           False         False          False           False
# 951       False           False         False          False           False
# 952       False           False         False          False           False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# bpm                     0
# music_mode              0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
pd.isnull(df).sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# bpm                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
# yearly_released=df.groupby(['released_year'],as_index==False).sum
ax=sns.countplot(x="released_year", data=df)
sns.set(rc={'figure.figsize':(25,5)})
for bars in ax.containers:                      
    ax.bar_label(bars)
# Out:
# c:\Program Files\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Program Files\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Program Files\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# As per the data most of the songs are released in year 2022

# %%
df.rename(columns={'mode':'music_mode'}, inplace=True)
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  in_deezer_charts  \
# ...

# %%
df['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                 34
# The Weeknd                   22
# Bad Bunny                    19
# SZA                          19
# Harry Styles                 17
#                              ..
# Karol G, Ovy On The Drums     1
# Coolio, L.V.                  1
# Kordhell                      1
# Kenia OS                      1
# Feid, Sech, Jhayco            1
# Name: count, Length: 645, dtype: int64

# %%
df.hist(column=df.columns, 
              color='black', 
              figsize=(20,20), 
              bins=10, 
              rwidth=0.9, 
              grid=False 
             )
mp.show()

# %%
df.describe(include=['0']).T
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\252ha\Desktop\DATA ANALYST\data_analytics\spotigy_analysis.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/252ha/Desktop/DATA%20ANALYST/data_analytics/spotigy_analysis.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> df.describe(include=['0']).T
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\generic.py:11537, in NDFrame.describe(self, percentiles, include, exclude)
#   11295 @final
#   11296 def describe(
#   11297     self,
#    (...)
#   11300     exclude=None,
#   11301 ) -> Self:
#   11302     """
#   11303     Generate descriptive statistics.
#   11304
#    (...)
#   11535     max            NaN      3.0
#   11536     """
# > 11537     return describe_ndframe(
#   11538         obj=self,
#   11539         include=include,
#   11540         exclude=exclude,
# ...

# %%
ax = df['music_mode'].value_counts().plot(kind='barh', figsize=(10,2), grid=False)
mp.show()
